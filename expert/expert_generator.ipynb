# %%
import spacy
nlp = spacy.load("en_core_web_lg")
import pandas as pd
import wordninja as wn

# %%
def find_words(instring, prefix = '', words = None):
    if not instring:
        return []
    if words is None:
        words = set()
        with open('/usr/share/dict/words') as f:
            for line in f:
                words.add(line.strip())
    if (not prefix) and (instring in words):
        return [instring]
    prefix, suffix = prefix + instring[0], instring[1:]
    solutions = []
    # Case 1: prefix in solution
    if prefix in words:
        try:
            solutions.append([prefix] + find_words(suffix, '', words))
        except ValueError:
            pass
    # Case 2: prefix not in solution
    try:
        solutions.append(find_words(suffix, prefix, words))
    except ValueError:
        pass
    if solutions:
        return sorted(solutions,
                      key = lambda solution: [len(word) for word in solution],
                      reverse = True)[0]
    else:
        raise ValueError('no solution')

# %%
from math import log

# Build a cost dictionary, assuming Zipf's law and cost = -math.log(probability).
words = open("words-by-frequency.txt").read().split()
wordcost = dict((k, log((i+1)*log(len(words)))) for i,k in enumerate(words))
maxword = max(len(x) for x in words)

def infer_spaces(s):
    """Uses dynamic programming to infer the location of spaces in a string
    without spaces."""

    # Find the best match for the i first characters, assuming cost has
    # been built for the i-1 first characters.
    # Returns a pair (match_cost, match_length).
    def best_match(i):
        candidates = enumerate(reversed(cost[max(0, i-maxword):i]))
        return min((c + wordcost.get(s[i-k-1:i], 9e999), k+1) for k,c in candidates)

    # Build the cost array.
    cost = [0]
    for i in range(1,len(s)+1):
        c,k = best_match(i)
        cost.append(c)

    # Backtrack to recover the minimal-cost string.
    out = []
    i = len(s)
    while i>0:
        c,k = best_match(i)
        assert c == cost[i]
        out.append(s[i-k:i])
        i -= k

    return " ".join(reversed(out))
which you can use with

# %%
words = set()
with open('/usr/share/dict/words') as f:
    for line in f:
        words.add(line.strip())

solutions = {}
def find_words(instring):
    # First check if instring is in the dictionnary
    if instring in words:
        return [instring]
    # No... But maybe it's a result we already computed
    if instring in solutions:
        return solutions[instring]
    # Nope. Try to split the string at all position to recursively search for results
    best_solution = None
    for i in range(1, len(instring) - 1):
        part1 = find_words(instring[:i])
        part2 = find_words(instring[i:])
        # Both parts MUST have a solution
        if part1 is None or part2 is None:
            continue
        solution = part1 + part2
        # Is the solution found "better" than the previous one?
        if best_solution is None or len(solution) < len(best_solution):
            best_solution = solution
    # Remember (memoize) this solution to avoid having to recompute it
    solutions[instring] = best_solution
    return best_solution

# %%
import re, string, random, glob, operator, heapq
from collections import defaultdict
from math import log10

def memo(f):
    "Memoize function f."
    table = {}
    def fmemo(*args):
        if args not in table:
            table[args] = f(*args)
        return table[args]
    fmemo.memo = table
    return fmemo

def test(verbose=None):
    """Run some tests, taken from the chapter.
    Since the hillclimbing algorithm is randomized, some tests may fail."""
    import doctest
    print 'Running tests...'
    doctest.testfile('ngrams-test.txt', verbose=verbose)

################ Word Segmentation (p. 223)

@memo
def segment(text):
    "Return a list of words that is the best segmentation of text."
    if not text: return []
    candidates = ([first]+segment(rem) for first,rem in splits(text))
    return max(candidates, key=Pwords)

def splits(text, L=20):
    "Return a list of all possible (first, rem) pairs, len(first)<=L."
    return [(text[:i+1], text[i+1:]) 
            for i in range(min(len(text), L))]

def Pwords(words): 
    "The Naive Bayes probability of a sequence of words."
    return product(Pw(w) for w in words)

#### Support functions (p. 224)

def product(nums):
    "Return the product of a sequence of numbers."
    return reduce(operator.mul, nums, 1)

class Pdist(dict):
    "A probability distribution estimated from counts in datafile."
    def __init__(self, data=[], N=None, missingfn=None):
        for key,count in data:
            self[key] = self.get(key, 0) + int(count)
        self.N = float(N or sum(self.itervalues()))
        self.missingfn = missingfn or (lambda k, N: 1./N)
    def __call__(self, key): 
        if key in self: return self[key]/self.N  
        else: return self.missingfn(key, self.N)

def datafile(name, sep='\t'):
    "Read key,value pairs from file."
    for line in file(name):
        yield line.split(sep)

def avoid_long_words(key, N):
    "Estimate the probability of an unknown word."
    return 10./(N * 10**len(key))

N = 1024908267229 ## Number of tokens

Pw  = Pdist(datafile('count_1w.txt'), N, avoid_long_words)

#### segment2: second version, with bigram counts, (p. 226-227)

def cPw(word, prev):
    "Conditional probability of word, given previous word."
    try:
        return P2w[prev + ' ' + word]/float(Pw[prev])
    except KeyError:
        return Pw(word)

P2w = Pdist(datafile('count_2w.txt'), N)

@memo 
def segment2(text, prev='<S>'): 
    "Return (log P(words), words), where words is the best segmentation." 
    if not text: return 0.0, [] 
    candidates = [combine(log10(cPw(first, prev)), first, segment2(rem, first)) 
                  for first,rem in splits(text)] 
    return max(candidates)

# %%
labels = ['Utility','Natural Language Processing','Application Performance Manager','Network','Database','Interpreter','Multi Thread','Error Handling','Logging','Language','Data Structure',
          'Software Development and IT Operations','Internationalization','Setup','Logic','Microservices','Machine Learning','Test','Search','Input and Output','User Interface','Parser','Security',
          'Cloud','Big Data','Event Handling','Application','Geographic Information System ']
debug = 'N'

def semantic_match(api):
    #semantic matching
    #comparator = sc(sentencizer=True)
    #comparator = sc(spacy_model='en_core_web_lg')
        
    api_classes = ' '
    api_list = []    
    if debug == 'Y':
        print(api, "<-api")
    
    #count = 0
    max_sim = 0
    api_selected = ' '
    api_clean = api.replace(".", " ")
    api_clean = api_clean.replace("/", " ")
    
    #api_class = api_clean.split(" ")
    api_class_list = api_clean.rsplit(' ', 1)

    api_class = api_class_list[len(api_class_list)-1]
    api_begin = api_class_list[0]
    api_list = wn.split(api_class)
    
    api_classes = api_classes.join(api_list)
    
    api_new = str(api_begin)+ ' '+ str(api_classes)
    if debug == 'Y':
        print('class list:',api_class_list)
        print('class:',api_class)
        print('list:',api_list)
        print('classes:',api_classes)

        print(type(api_new))
        print("api_new:",api_new)        

    for k in range(len(labels)):
        label = labels[k]
            
        doc1 = nlp(api_new)
        doc2 = nlp(label)
        #similarity = comparator.compare_phrases(doc1, doc2)
        similarity = doc1.similarity(doc2)
        if debug == 'Y':
            print(doc1, "<->", doc2, similarity)
            
        if (similarity > max_sim):
            max_sim = similarity
            api_selected = label
            if debug == 'Y':
                print("new max similarity:",similarity, 'doc2:', doc2)

            #count = count + 1
            
    if debug == 'Y':
        print("max similarity:",max_sim, 'api_selected:', api_selected)
    
    return api_selected+','+str(round(max_sim,2))

# %%
def __main__():
    
    #csv created by: select general, specific, class, api_name from "API_specific" a, "API" b where a.api_name_fk = b.api_name

    api_specific = pd.read_csv( './api_specific_class.csv')
    api_specific["corpus"] = api_specific["general"].map(str)+ ' ' + api_specific["specific"].map(str)+ ' ' + api_specific["class"].map(str)


    api_specific['expert'] = api_specific['corpus'].apply(semantic_match)

    api_specific.to_csv( './api_specific_expert.csv')

# %%
__main__()
# Out:
# <ipython-input-2-a4053a3d7fa9>:47: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = doc1.similarity(doc2)

# %%
api_expert = pd.read_csv( './api_specific_expert.csv')

api_grouped = api_expert['expert'].groupby([api_expert.general]).apply(set).reset_index()

api_grouped.head()
# Out:
#               general                                             expert
# 0   AdditionalAnswers              {Geographic Information System ,0.54}
# 1  AdditionalMatchers                               {Event Handling,0.5}
# 2             Answers  {Error Handling,0.52, Software Development and...
# 3    ArgumentMatchers                                    {Big Data,0.44}
# 4          BDDMockito                                        {Test,0.45}

# %%
api_grouped.to_csv( './api_expert_review.csv', encoding='utf-8')

# %%
pd.options.display.max_seq_items = 2000
pd.options.display.max_colwidth = 900
pd.options.display.max_rows = 999

# %%
 api_grouped
# Out:
#                                                              general  \
# 0                                                  AdditionalAnswers
# 1                                                 AdditionalMatchers
# 2                                                            Answers
# 3                                                   ArgumentMatchers
# 4                                                         BDDMockito
# 5                                       ExceededMemoryLimitException
# 6                                        ExceededSpillLimitException
# 7                                                               JSci
# 8                                                           Matchers
# 9                                                            Mockito
# 10                                                MockitoAnnotations
# 11                                                  PrestoMediaTypes
# 12                                                    RowPageBuilder
# 13                                                   RowPagesBuilder
# 14                                               SequencePageBuilder
# 15                                                           Session
# 16                                                  SessionTestUtils
# 17                                           SystemSessionProperties
# 18                                                TransactionBuilder
# 19                                                          accumulo
# 20                                                          airhacks
# 21                                                           airlift
# 22                                                           alluxio
# 23                                                        annotation
# 24                                                             antlr
# 25                                                               api
# 26                                               applicationinsights
# 27                                                      architecture
# 28                                                             array
# 29                                                           assertj
# 30                                                                at
# 31                                                              atop
# 32                                                                au
# 33                                                              auth
# 34                                                              auto
# 35                                                              avro
# 36                                                               awt
# 37                                                         benchmark
# 38                                                             block
# 39                                                              bson
# 40                                                          bytecode
# 41                                                             cache
# 42                                                           caliper
# 43                                                         cassandra
# 44                                                  checkerframework
# 45                                                       clearspring
# 46                                                               cli
# 47                                                            client
# 48                                                             cloud
# 49                                                           codegen
# 50                                                            common
# 51                                                           commons
# 52                                                     configuration
# 53                                                         connector
# 54                                                        controlsfx
# 55                                                              cost
# 56                                                          creation
# 57                                                           curator
# 58                                                          datastax
# 59                                                                de
# 60                                                           decoder
# 61                                                   did not succeed
# 62                                                        dispatcher
# 63                                                             drift
# 64                                                             druid
# 65                                                          easymock
# 66                                                           eclipse
# 67                                                     elasticsearch
# 68                                                        elemental2
# 69                                                        errorprone
# 70                                                  esotericsoftware
# 71                                                              esri
# 72                                                             esult
# 73                                                             event
# 74                                                     eventlistener
# 75                                                           example
# 76                                                        exceptions
# 77                                                         execution
# 78                                                            export
# 79                                                       expressions
# 80                                                   failureDetector
# 81                                                         fasterxml
# 82                                                         fastparse
# 83                                                            format
# 84                                                           formats
# 85                                                 functionNamespace
# 86                                                        fusesource
# 87                                                            fxmisc
# 88                                                        geospatial
# 89                                                            github
# 90                                                              gson
# 91                                                               gui
# 92                                                               gwt
# 93                                                                h2
# 94                                                            hadoop
# 95                                                          hamcrest
# 96                                                          handlers
# 97                                                              hive
# 98                                                              http
# 99                                                              hudi
# 100                                                          iceberg
# 101                                                             ietf
# 102                                                             impl
# 103                                                            index
# 104                                                             info
# 105                                                           inject
# 106                                                         intellij
# 107                                                         internal
# 108                                                       invocation
# 109                                                               io
# 110                                                               it
# 111                                                           j2objc
# 112                                                           javafx
# 113                                                            javax
# 114                                                          jbibtex
# 115                                                             jdbc
# 116                                                             jdbi
# 117                                                          jfoenix
# 118                                                          jgrapht
# 119                                                            jline
# 120                                                             joda
# 121                                                        jsinterop
# 122                                                             json
# 123                                                            jsoup
# 124                                                            junit
# 125                                                            kafka
# 126                                                             kong
# 127                                                          kordamp
# 128                                                             kudu
# 129                                                             lang
# 130                                                           libsvm
# 131                                                        listeners
# 132                                                        localfile
# 133                                                     locationtech
# 134                                                            log4j
# 135                                                          logging
# 136                                                            logic
# 137                                                           lucene
# 138                                                       management
# 139                                                          mashape
# 140                                                         matching
# 141                                                             math
# 142                                                           memory
# 143                                                         metadata
# 144                                                          metrics
# 145                                                       migrations
# 146                                                             misc
# 147                                                               ml
# 148                                                             mock
# 149                                                     mockitousage
# 150                                                      mockitoutil
# 151                                                            model
# 152                                                       moduletest
# 153                                                          mongodb
# 154                                                     myanmartools
# 155                                                            mysql
# 156                                                              net
# 157                                             ng in unknown format
# 158                                                              nio
# 159        nt element to a high‐quality teacher‐student relationship
# 160                                                          nt here
# 161                                                         nt sense
# 162         nt to not call {@link #dispatch} while holding any locks
# 163                                                          oOpen 2
# 164                                                        objectweb
# 165                                                        objenesis
# 166                                                          okhttp3
# 167                                                 on line " + this
# 168                                                          openjdk
# 169                                                       opentest4j
# 170                                                         operator
# 171                                                           oracle
# 172                                                              orc
# 173  ormatsList + outFormatsList + "\nPlease report issues at https:
# 174                                                             osgi
# 175                                                         osgitest
# 176                                                          parquet
# 177                                                         password
# 178                                                     pcollections
# 179                                                           pdfbox
# 180                                                            pinot
# 181                                                           plugin
# 182                                                          plugins
# 183                                                       postgresql
# 184                                                      preferences
# 185                                                            proxy
# 186                                                          quality
# 187                                                                r
# 188                r exists only to enable `--importToOpen someEntry
# 189                                      r has thrown an IOException
# 190               r is capable of importing NEP messages into JabRef
# 191  r parses text format citations using the online API of FreeCite
# 192                                                           raptor
# 193                                                           rcfile
# 194                                                             re2j
# 195                                                          reactfx
# 196                                                  reactivestreams
# 197                                                            redis
# 198                                                      reflections
# 199                                                          regions
# 200                                                   resourceGroups
# 201                                                  resourcemanager
# 202                                                    roaringbitmap
# 203                                                          runners
# 204                                                            scala
# 205                                                           search
# 206                                                         security
# 207                                                           server
# 208                                                         services
# 209                                                          session
# 210                                                            skife
# 211                                                            slf4j
# 212                                                         sonatype
# 213                                                           source
# 214                                                            spark
# 215                                                              spi
# 216                                                          spiller
# 217                                                            split
# 218                                                          spotify
# 219                                                              sql
# 220                                                        sqlserver
# 221                                                             star
# 222                                                    statusservice
# 223                                                          storage
# 224                                                         stubbing
# 225                                                          support
# 226                                                         tartarus
# 227                                                          tdigest
# 228                                                         teradata
# 229                                                   testcontainers
# 230                                                           testfx
# 231                                                          testing
# 232                                                           testng
# 233                                                            tests
# 234                                                        testutils
# 235                                                             text
# 236                                                       thirdparty
# 237                                                        this file
# 238                                                           thrift
# 239                                                             tika
# 240                                                             time
# 241                                                          tngtech
# 242                                                       tobiasdiez
# 243                                                            tools
# 244                                                            tpcds
# 245                                                             tpch
# 246                                                      transaction
# 247                                                             type
# 248                                                              udf
# 249                                                        undefined
# 250                                                             util
# 251                                                     verification
# 252                                                         verifier
# 253                                                          version
# 254                                                          vladsch
# 255                                                              w3c
# 256                                                          weakref
# 257                                                              xml
# 258                                                          xmlunit
# 259                                                           xmpbox
# 260                                                        zookeeper
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   expert
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  {Geographic Information System ,0.54}
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {Event Handling,0.5}
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {Error Handling,0.52, Software Development and IT Operations,0.58}
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {Big Data,0.44}
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            {Test,0.45}
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {Error Handling,0.6}
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  {Error Handling,0.53}
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  {Data Structure,0.53}
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  {Event Handling,0.34}
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       {Test,0.3, Parser,0.3, Parser,0.23, Parser,0.22}
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         {Software Development and IT Operations,0.49}
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {Big Data,0.47, Application,0.59, Search,0.36}
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         {Search,0.48}
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       {Big Data,0.48}
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {Data Structure,0.57}
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      {Event Handling,0.47, Application Performance Manager,0.59, Application Performance Manager,0.5}
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {Test,0.82}
# 17   {Input and Output,0.79, Big Data,0.57, Software Development and IT Operations,0.66, Input and Output,0.59, Big Data,0.62, Data Structure,0.61, Software Development and IT Operations,0.32, Data Structure,0.55, Input and Output,0.63, Database,0.59, Data Structure,0.49, Data Structure,0.52, Input and Output,0.47, Error Handling,0.63, Big Data,0.61, Software Development and IT Operations,0.68, Software Development and IT Operations,0.61, Software Development and IT Operations,0.63, Software Development and IT Operations,0.46, Input and Output,0.61, Software Development and IT Operations,0.58, Data Structure,0.64, Data Structure,0.57, Input and Output,0.74, Big Data,0.37, Software Development and IT Operations,0.7, User Interface,0.63, Data Structure,0.51, Software Development and IT Operations,0.55, Big Data,0.67, Data Structure,0.7, Big Data,0.51, Software Development and IT Operations,...
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                {Application Performance Manager,0.55}
# 19   {Big Data,0.57, Multi Thread,0.5, Big Data,0.56, Data Structure,0.61, Input and Output,0.58, User Interface,0.59, Multi Thread,0.38, Data Structure,0.55, Data Structure,0.66, Data Structure,0.31, Big Data,0.5, User Interface,0.21, Big Data,0.53, Big Data,0.55, Multi Thread,0.49, Data Structure,0.49, Parser,0.53, Setup,0.54, Error Handling,0.67, Data Structure,0.62, Database,0.53, Multi Thread,0.46, Big Data,0.58, Software Development and IT Operations,0.57, Software Development and IT Operations,0.63, User Interface,0.5, User Interface,0.56, Setup,0.53, Error Handling,0.66, Parser,0.31, Setup,0.47, Security,0.66, Software Development and IT Operations,0.53, Data Structure,0.47, Data Structure,0.57, Multi Thread,0.2, Application Performance Manager,0.46, User Interface,0.51, Parser,0.39, Multi Thread,0.32, Multi Thread,0.31, Data Structure,0.51, Multi Thread,0.53, Data Structure,0.54,...
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {Setup,0.26, Setup,0.42, Geographic Information System ,0.49, Application Performance Manager,0.34}
# 21   {Interpreter,0.39, Test,0.62, Parser,0.36, Geographic Information System ,0.52, Security,0.68, Parser,0.46, Multi Thread,0.62, Geographic Information System ,0.47, Input and Output,0.47, Multi Thread,0.37, Error Handling,0.49, Setup,0.63, User Interface,0.53, Parser,0.37, Parser,0.47, Error Handling,0.55, Geographic Information System ,0.55, Database,0.55, Test,0.74, Logging,0.52, Error Handling,0.69, Database,0.5, Setup,0.64, Software Development and IT Operations,0.54, Event Handling,0.77, Error Handling,0.58, Big Data,0.43, Event Handling,0.71, Event Handling,0.81, Parser,0.56, Error Handling,0.54, Software Development and IT Operations,0.51, Error Handling,0.53, Setup,0.6, Geographic Information System ,0.44, Event Handling,0.72, User Interface,0.59, Software Development and IT Operations,0.43, Application Performance Manager,0.51, Parser,0.45, Setup,0.61, Data Structure,0.49, Bi...
# 22                                                                                                {Error Handling,0.61, Error Handling,0.64, Event Handling,0.39, Data Structure,0.69, Data Structure,0.55, Error Handling,0.57, Big Data,0.74, Setup,0.51, Application Performance Manager,0.64, Logic,0.48, Application Performance Manager,0.66, User Interface,0.48, Input and Output,0.34, Parser,0.5, Database,0.57, Data Structure,0.49, Geographic Information System ,0.68, Data Structure,0.71, Natural Language Processing,0.26, Big Data,0.72, User Interface,0.53, Database,0.51, User Interface,0.63, Application Performance Manager,0.61, Error Handling,0.7, Software Development and IT Operations,0.54, User Interface,0.74, Setup,0.56, Data Structure,0.78, Application Performance Manager,0.73, Big Data,0.77, Data Structure,0.58, Data Structure,0.59, Data Structure,0.68, Data Structure,0.75, Big Data,0.59}
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {Data Structure,0.65}
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {Parser,0.63, Parser,0.62, Parser,0.55, Parser,0.54, Parser,0.48, Parser,0.45, Parser,0.46, Parser,0.44, Parser,0.58, Parser,0.65, Parser,0.69, Parser,0.61, Error Handling,0.63, Parser,0.47, Parser,0.57, Parser,0.4, Parser,0.39, Parser,0.59, Parser,0.41, Parser,0.6, Error Handling,0.58, Parser,0.67, Parser,0.66, Error Handling,0.6, Parser,0.51, Parser,0.49, Parser,0.56, Parser,0.77}
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          {Error Handling,0.52, User Interface,0.49, User Interface,0.64, Parser,0.45}
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          {Data Structure,0.52, Application,0.65, Data Structure,0.58, Software Development and IT Operations,0.72, Data Structure,0.43, Data Structure,0.46, Logging,0.34, User Interface,0.6, Software Development and IT Operations,0.61, Data Structure,0.56, User Interface,0.55}
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {Software Development and IT Operations,0.65, Software Development and IT Operations,0.59, Software Development and IT Operations,0.7, Software Development and IT Operations,0.72}
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         {Big Data,0.63, Input and Output,0.59, Big Data,0.61, Big Data,0.56, Big Data,0.62, Data Structure,0.62, Big Data,0.65, Data Structure,0.61, Data Structure,0.55, Data Structure,0.66, Data Structure,0.6, Data Structure,0.63, Data Structure,0.67, Data Structure,0.54, Big Data,0.64, Data Structure,0.57}
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {Logic,0.58, Data Structure,0.62, Software Development and IT Operations,0.57, Software Development and IT Operations,0.56, Data Structure,0.61, Logic,0.46, Logic,0.43, Data Structure,0.66, Data Structure,0.63, Logic,0.56, Data Structure,0.6}
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {Big Data,0.28, Big Data,0.52}
# ...
# 244                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  {Database,0.48, Big Data,0.48, Error Handling,0.46, Big Data,0.53, Setup,0.44, Error Handling,0.37}
# 245                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {Big Data,0.57, Data Structure,0.77, Input and Output,0.5, Data Structure,0.74, Data Structure,0.55, Database,0.41, Big Data,0.53, Parser,0.54, Big Data,0.55, Data Structure,0.49, Application Performance Manager,0.42, Input and Output,0.45, Error Handling,0.49, Big Data,0.46, User Interface,0.42, Utility,0.47, Input and Output,0.44, User Interface,0.39, Data Structure,0.48, Input and Output,0.46, Error Handling,0.42}
# 246                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {Error Handling,0.51, Application Performance Manager,0.52, User Interface,0.62, Application Performance Manager,0.62, Application Performance Manager,0.6, User Interface,0.5, Application Performance Manager,0.64, Application Performance Manager,0.61, Application Performance Manager,0.7, Application Performance Manager,0.66}
# 247  {Natural Language Processing,0.57, Input and Output,0.59, Big Data,0.56, Input and Output,0.55, Big Data,0.62, Input and Output,0.49, Data Structure,0.61, Input and Output,0.58, Software Development and IT Operations,0.64, Data Structure,0.45, Data Structure,0.55, User Interface,0.59, Input and Output,0.53, Input and Output,0.51, Data Structure,0.66, Data Structure,0.67, Big Data,0.54, Big Data,0.5, Big Data,0.55, User Interface,0.57, Data Structure,0.71, Parser,0.53, Multi Thread,0.29, Big Data,0.61, Data Structure,0.52, Data Structure,0.42, Data Structure,0.62, Big Data,0.58, Software Development and IT Operations,0.61, Software Development and IT Operations,0.63, Big Data,0.68, User Interface,0.56, User Interface,0.53, User Interface,0.55, Input and Output,0.52, Input and Output,0.61, Data Structure,0.47, Data Structure,0.57, Data Structure,0.64, Big Data,0.47, Geographic Informat...
# 248                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {Error Handling,0.4}
# 249                                                                                                                                                                                                                                                                                                                                     {Error Handling,0.53, Big Data,0.57, Error Handling,0.64, Error Handling,0.51, Data Structure,0.61, Error Handling,0.57, Error Handling,0.44, Error Handling,0.5, Error Handling,0.49, Error Handling,0.59, User Interface,0.55, Error Handling,0.55, Error Handling,0.62, User Interface,0.51, Test,0.65, Error Handling,0.41, Error Handling,0.56, Error Handling,0.38, Error Handling,0.48, Error Handling,0.52, Parser,0.41, Error Handling,0.65, Error Handling,0.6, Input and Output,0.65, User Interface,0.6, Parser,0.35, Error Handling,0.43, Error Handling,0.54, Error Handling,0.42}
# 250  {Input and Output,0.59, Database,0.48, Application,0.54, Input and Output,0.58, Parser,0.36, Input and Output,0.53, Parser,0.48, Parser,0.46, Interpreter,0.42, Input and Output,0.47, Error Handling,0.49, Test,0.57, Error Handling,0.46, User Interface,0.53, Input and Output,0.69, Utility,0.41, Setup,0.47, Application Performance Manager,0.53, Parser,0.37, Parser,0.47, Error Handling,0.55, Data Structure,0.57, Application,0.31, Big Data,0.47, Error Handling,0.8, Utility,0.33, Utility,0.23, Application,0.41, Error Handling,0.4, Error Handling,0.69, Parser,0.52, Big Data,0.41, Database,0.5, Utility,0.49, Setup,0.56, Utility,0.53, Error Handling,0.58, User Interface,0.43, Utility,0.37, Parser,0.56, Software Development and IT Operations,0.62, Error Handling,0.54, Logging,0.7, Logging,0.66, Multi Thread,0.35, Error Handling,0.53, Error Handling,0.61, Application Performance Manager,0.63, L...
# 251                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  {Application,0.52, Software Development and IT Operations,0.56, Application,0.57, Application,0.55}
# 252  {Database,0.48, Data Structure,0.69, Test,0.7, Application,0.37, Parser,0.46, Test,0.69, Application Performance Manager,0.53, Parser,0.37, Test,0.74, Error Handling,0.55, Data Structure,0.57, Database,0.55, Parser,0.52, Database,0.5, Event Handling,0.6, Parser,0.64, Test,0.53, Logic,0.6, User Interface,0.61, Software Development and IT Operations,0.54, Error Handling,0.58, Data Structure,0.65, User Interface,0.68, Database,0.63, User Interface,0.6, Error Handling,0.56, Parser,0.56, Error Handling,0.54, Test,0.72, Software Development and IT Operations,0.66, Data Structure,0.55, Error Handling,0.57, Logic,0.56, Input and Output,0.63, Parser,0.38, Data Structure,0.76, Error Handling,0.59, Logic,0.57, Software Development and IT Operations,0.63, User Interface,0.58, Parser,0.57, Database,0.44, Error Handling,0.62, Parser,0.4, User Interface,0.63, Application,0.58, Data Structure,0.6, D...
# 253                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {Application,0.43}
# 254                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {Parser,1.0, Data Structure,0.74, User Interface,0.5, User Interface,0.42, Parser,0.34, Software Development and IT Operations,0.62}
# 255                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {Event Handling,0.46, Event Handling,0.45, Parser,0.39, Parser,0.52, Data Structure,0.56, Parser,0.49, Parser,0.48, Parser,0.47}
# 256                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      {Parser,0.4, Internationalization,0.26, Test,0.57, User Interface,0.52, Interpreter,0.31, Logging,0.36, User Interface,0.42, Error Handling,0.34, Logging,0.33}
# 257                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {Input and Output,0.7, Error Handling,0.69, Parser,0.4, Parser,0.57}
# 258                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {Application Performance Manager,0.4, Input and Output,0.72, User Interface,0.55, Error Handling,0.22, Test,0.38}
# 259                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {Parser,0.69, Input and Output,0.51, Database,0.52, Parser,0.64, User Interface,0.44, Parser,0.46}
# 260                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                {Database,0.51, Interpreter,0.34, User Interface,0.46, User Interface,0.5, Database,0.47, Setup,0.56}
